# %%
# h1ttps://eprint.iacr.org/2015/525

# 4.1
from py_ecc.bn128 import G1, G2, pairing, add, multiply, neg, curve_order, eq, final_exponentiate

# functions
def string_to_int(message):
    return int.from_bytes(message, byteorder='big')

# keygen
def user_setup():
    # generate random field elements to scale G1
    x = 10
    y = 15

    X2 = multiply(G2, x)
    Y2 = multiply(G2, y)

    sk1 = {"x": x, "y": y}
    pk2 = {"X2": X2, "Y2": Y2}

    return sk1, pk2

def sign(sk1, message):
    h = 77
    H1 = multiply(G1, h)
    s1 = H1
    s2 = multiply(H1, sk1['x'] + sk1['y'] * string_to_int(message))
    return {"s1": s1, "s2": s2}

def verify(pk2, message, sigma):
    assert not eq(sigma['s1'],G1)
    lhs2 = add(pk2['X2'], multiply(pk2['Y2'], string_to_int(message)))
    lhs_pairing = pairing(lhs2, sigma['s1'])

    rhs_pairing = pairing(G2, sigma['s2'])

    assert(eq(lhs_pairing, rhs_pairing)), "pairing verification failed"


def execute():
    # Your main code here
    print("This is the main function.")

    sk1, pk2 = user_setup()
    print(sk1['x'])

    m1 = b"sam polgar"

    sigma = sign(sk1, m1)

    m2 = b"not sam polgar"

    verify(pk2, m2, sigma)

execute()
# Out:
# This is the main function.
# 10
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /Users/spolgar/Documents/projects/research/anonymous-credentials/pointcheval-sanders.ipynb Cell 1 line 5
#      <a href='vscode-notebook-cell:/Users/spolgar/Documents/projects/research/anonymous-credentials/pointcheval-sanders.ipynb#W1sZmlsZQ%3D%3D?line=51'>52</a>     m2 = b"not sam polgar"
#      <a href='vscode-notebook-cell:/Users/spolgar/Documents/projects/research/anonymous-credentials/pointcheval-sanders.ipynb#W1sZmlsZQ%3D%3D?line=53'>54</a>     verify(pk2, m2, sigma)
# ---> <a href='vscode-notebook-cell:/Users/spolgar/Documents/projects/research/anonymous-credentials/pointcheval-sanders.ipynb#W1sZmlsZQ%3D%3D?line=55'>56</a> execute()
#
# /Users/spolgar/Documents/projects/research/anonymous-credentials/pointcheval-sanders.ipynb Cell 1 line 5
#      <a href='vscode-notebook-cell:/Users/spolgar/Documents/projects/research/anonymous-credentials/pointcheval-sanders.ipynb#W1sZmlsZQ%3D%3D?line=49'>50</a> sigma = sign(sk1, m1)
#      <a href='vscode-notebook-cell:/Users/spolgar/Documents/projects/research/anonymous-credentials/pointcheval-sanders.ipynb#W1sZmlsZQ%3D%3D?line=51'>52</a> m2 = b"not sam polgar"
# ---> <a href='vscode-notebook-cell:/Users/spolgar/Documents/projects/research/anonymous-credentials/pointcheval-sanders.ipynb#W1sZmlsZQ%3D%3D?line=53'>54</a> verify(pk2, m2, sigma)
#
# /Users/spolgar/Documents/projects/research/anonymous-credentials/pointcheval-sanders.ipynb Cell 1 line 3
#      <a href='vscode-notebook-cell:/Users/spolgar/Documents/projects/research/anonymous-credentials/pointcheval-sanders.ipynb#W1sZmlsZQ%3D%3D?line=33'>34</a> lhs_pairing = pairing(lhs2, sigma['s1'])
#      <a href='vscode-notebook-cell:/Users/spolgar/Documents/projects/research/anonymous-credentials/pointcheval-sanders.ipynb#W1sZmlsZQ%3D%3D?line=35'>36</a> rhs_pairing = pairing(G2, sigma['s2'])
# ---> <a href='vscode-notebook-cell:/Users/spolgar/Documents/projects/research/anonymous-credentials/pointcheval-sanders.ipynb#W1sZmlsZQ%3D%3D?line=37'>38</a> assert(eq(lhs_pairing, rhs_pairing)), "pairing verification failed"
#
# AssertionError: pairing verification failed

# %%
# https://eprint.iacr.org/2015/525

# 4.2
from py_ecc.bn128 import G1, G2, pairing, add, multiply, neg, curve_order, eq
import hashlib

# functions


def string_to_int(message):
    return int.from_bytes(message, byteorder='big')

# keygen


# random field elements to scale G2
x = 10
y1 = 15
y2 = 20
y3 = 25
y4 = 30

X = multiply(G2, x)
Y1 = multiply(G2, y1)
Y2 = multiply(G2, y2)
Y3 = multiply(G2, y3)
Y4 = multiply(G2, y4)

sk = [x, y1, y2, y3, y4]
pk = [X, Y1, Y2, Y3, Y4]

# sign
m1 = b"sam"
m2 = b"polgar"
m3 = b"student"
m4 = b"1/1/2000"

m1_int = string_to_int(m1)
m2_int = string_to_int(m2)
m3_int = string_to_int(m3)
m4_int = string_to_int(m4)

h = 77
H = multiply(G1, h)

h_scalar = x + y1 * m1_int + y2 * m2_int + y3 * m3_int + y4 * m4_int
H = multiply(G1, h_scalar)

# verify
